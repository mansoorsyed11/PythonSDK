# %%
# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
from azureml.core import Workspace, Dataset,Experiment, Datastore


subscription_id= 'eb5a257a-76e2-472d-9fdc-7f9b3172fcf6'
resource_group = 'rg-smth-3788'
workspace_name = 'smth-3788'
az_store       = Datastore.get(workspace_name, 'azureml_ds_b01')

workspace = Workspace(subscription_id, resource_group, workspace_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\msyed\OneDrive - Kagool Ltd\Documents\Experiments\Exp1\Untitled-1.ipynb Cell 1 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/msyed/OneDrive%20-%20Kagool%20Ltd/Documents/Experiments/Exp1/Untitled-1.ipynb#ch0000000?line=6'>7</a> resource_group = 'rg-smth-3788'
#       <a href='vscode-notebook-cell:/c%3A/Users/msyed/OneDrive%20-%20Kagool%20Ltd/Documents/Experiments/Exp1/Untitled-1.ipynb#ch0000000?line=7'>8</a> workspace_name = 'smth-3788'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/msyed/OneDrive%20-%20Kagool%20Ltd/Documents/Experiments/Exp1/Untitled-1.ipynb#ch0000000?line=8'>9</a> az_store       = Datastore.get(workspace_name, 'azureml_ds_b01')
#      <a href='vscode-notebook-cell:/c%3A/Users/msyed/OneDrive%20-%20Kagool%20Ltd/Documents/Experiments/Exp1/Untitled-1.ipynb#ch0000000?line=10'>11</a> workspace = Workspace(subscription_id, resource_group, workspace_name)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/azureml/core/datastore.py:144, in Datastore.get(workspace, datastore_name)
#     126 @staticmethod
#     127 def get(workspace, datastore_name):
#     128     """Get a datastore by name. This is same as calling the constructor.
#     129
#     130     :param workspace: The workspace.
#    (...)
#     142             or azureml.data.dbfs_datastore.DBFSDatastore
#     143     """
# --> 144     return Datastore._client().get(workspace, datastore_name)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/azureml/data/datastore_client.py:70, in _DatastoreClient.get(workspace, datastore_name)
#      59 @staticmethod
#      60 def get(workspace, datastore_name):
#      61     """Get a datastore by name.
#      62
#      63     :param workspace: The workspace.
#    (...)
#      68     :rtype: typing.Union[AzureFileDatastore, AzureBlobDatastore]
#      69     """
# ---> 70     return _DatastoreClient._get(workspace, datastore_name)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/azureml/data/_exception_handler.py:16, in _handle_error_response_exception.<locals>.decorated(*args, **kwargs)
#      13 @wraps(f)
#      14 def decorated(*args, **kwargs):
#      15     try:
# ---> 16         return f(*args, **kwargs)
#      17     except ErrorResponseException as e:
#      18         if e.response.status_code < 500 and "(UserError)" in str(e):
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/azureml/data/datastore_client.py:717, in _DatastoreClient._get(ws, name, auth, host)
#     712 @staticmethod
#     713 @_handle_error_response_exception
#     714 def _get(ws, name, auth=None, host=None):
#     715     module_logger.debug("Getting datastore: {}".format(name))
# --> 717     client = _DatastoreClient._get_client(ws, auth, host)
#     718     datastore = client.data_stores.get(subscription_id=ws._subscription_id, resource_group_name=ws._resource_group,
#     719                                        workspace_name=ws._workspace_name, name=name,
#     720                                        custom_headers=_DatastoreClient._custom_headers)
#     722     module_logger.debug("Received DTO from the datastore service")
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/azureml/data/datastore_client.py:976, in _DatastoreClient._get_client(ws, auth, host)
#     973 @staticmethod
#     974 def _get_client(ws, auth, host):
#     975     host_env = os.environ.get('AZUREML_SERVICE_ENDPOINT')
# --> 976     auth = auth or ws._auth
#     977     host = host or host_env or get_service_url(
#     978         auth, _DatastoreClient._get_workspace_uri_path(ws._subscription_id, ws._resource_group,
#     979                                                        ws._workspace_name), ws._workspace_id, ws.discovery_url)
#     981     return RestClient(credentials=_DatastoreClient._get_basic_token_auth(auth), base_url=host)
#
# AttributeError: 'str' object has no attribute '_auth'

# %%
from azureml.core import Workspace, Dataset,Experiment, Datastore

# %%
dataset = Dataset.get_by_name(workspace, name='Real Est')
dataset.to_pandas_dataframe()
# Out:
#      transaction_date  house_age  transit_distance  local_convenience_stores  \
# 0            2012.917       32.0          84.87882                        10
# 1            2012.917       19.5         306.59470                         9
# 2            2013.583       13.3         561.98450                         5
# 3            2013.500       13.3         561.98450                         5
# 4            2012.833        5.0         390.56840                         5
# ..                ...        ...               ...                       ...
# 409          2013.000       13.7        4082.01500                         0
# 410          2012.667        5.6          90.45606                         9
# 411          2013.250       18.8         390.96960                         7
# 412          2013.000        8.1         104.81010                         5
# 413          2013.500        6.5          90.45606                         9
#
#      latitude  longitude  price_per_unit
# 0    24.98298  121.54024            37.9
# 1    24.98034  121.53951            42.2
# 2    24.98746  121.54391            47.3
# 3    24.98746  121.54391            54.8
# 4    24.97937  121.54245            43.1
# ..        ...        ...             ...
# 409  24.94155  121.50381            15.4
# 410  24.97433  121.54310            50.0
# 411  24.97923  121.53986            40.6
# 412  24.96674  121.54067            52.5
# 413  24.97433  121.54310            63.9
#
# [414 rows x 7 columns]

# %%
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
from azureml.core import Workspace, Dataset,Experiment, Datastore


subscription_id= 'eb5a257a-76e2-472d-9fdc-7f9b3172fcf6'
resource_group = 'rg-smth-3788'
workspace_name = 'smth-3788'
#az_store       = Datastore.get(workspace_name, 'azureml_ds_b01')

workspace = Workspace(subscription_id, resource_group, workspace_name)


# -----------------------------------------------------
# Create a datastore 
# -----------------------------------------------------
az_store = Datastore.register_azure_blob_container(
            workspace=workspace,
            datastore_name="azure_sdk_blob01", #create a name
            account_name="smth37881976232114", #storage account name
            container_name="mlexperiments", #container name
            account_key="oDGA8zdyZLE+sQdWx1bLczGA6kRVfw7Iq0NuNYg+wX1TEgTFidLGOaQ2gcC3PQeh2ourxYZklizigunxBB0WWA==") #storage access key
